# %% [markdown]
# <a href="https://colab.research.google.com/github/kazuhayase/study/blob/master/mls-seminar/notebooks/test_mls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. GitHubから最新のrequirements.txtを取得するためにリポジトリをクローン（またはファイルをアップロード）
# ※ 既にステップ1でノートブックを開いている場合は、以下のコマンドで環境だけ整えます

# もしリポジトリ全体を操作したい場合はクローンします
# !git clone https://github.com/kazuhayase/study.git

import os
os.chdir('study/mls-seminar')

# !pwd

# 2. Debian環境と同じライブラリをインストール
# ノートブックと同じ階層にrequirements.txtがある前提です
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'study' already exists and is not an empty directory.
# /content/study/mls-seminar
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 79.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.0/118.0 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 621.4/621.4 kB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.2/106.2 kB 8.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 動作確認：正規分布のプロット
data = np.random.standard_normal(1000)
plt.hist(data, bins=30, density=True, alpha=0.6, color='g')
plt.title("Environment Test: Normal Distribution")
plt.show()

print(f"Pandas version: {pd.__version__}")
