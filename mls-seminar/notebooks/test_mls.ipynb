# %% [markdown]
# <a href="https://colab.research.google.com/github/kazuhayase/study/blob/master/mls-seminar/notebooks/test_mls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys

# 1. Colab環境かどうかの判定
if 'google.colab' in sys.modules:
    # リポジトリの場所
    repo_path = '/content/study'
    project_path = os.path.join(repo_path, 'mls-seminar')

    # 2. リポジトリがなければクローン
    if not os.path.exists(repo_path):
        # GitHubのURLはご自身のに書き換えてください
        # !git clone https://github.com/kazuhayase/study.git

    # 3. 作業ディレクトリへ移動
    os.chdir(project_path)

    # 4. パスの追加（自作モジュール読み込み用）
    if project_path not in sys.path:
        sys.path.append(project_path)

    print(f"Environment: Google Colab / Directory: {os.getcwd()}")
else:
    print(f"Environment: Local Debian / Directory: {os.getcwd()}")
# Out:
# Environment: Google Colab / Directory: /content/study/mls-seminar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 動作確認：正規分布のプロット
data = np.random.standard_normal(1000)
plt.hist(data, bins=30, density=True, alpha=0.6, color='g')
plt.title("Environment Test: Normal Distribution")
plt.show()

print(f"Pandas version: {pd.__version__}")
# Out:
# Pandas version: 2.2.2

# %%
#Ctrl+S does git push, then we donot need this cell at all

from google.colab import userdata

## あなたの情報を入力してください
GIT_USER = "kazuhayase"
GIT_TOKEN = userdata.get('github_mls2025')
GIT_REPO = "study"

# リモートURLをトークン付きで再設定
#!git remote set-url origin https://{GIT_USER}:{GIT_TOKEN}@github.com/{GIT_USER}/{GIT_REPO}.git

# 変更をコミットしてPush
#!git config --global user.email "kazuyoshi.hayase@jcom.home.ne.jp"
#!git config --global user.name "Kazuyoshi Hayase"

#!git add .
#!git commit -m "Colabからの編集：[具体的な変更内容]"
#!git push origin master
