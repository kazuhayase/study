# %% [markdown]
# <a href="https://colab.research.google.com/github/kazuhayase/study/blob/master/GithubPush.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata

# あなたの情報を入力してください
GIT_USER = "kazuhayase"
GIT_TOKEN = userdata.get('github_mls2025')
GIT_REPO = "study"

# リモートURLをトークン付きで再設定
# !git remote set-url origin https://{GIT_USER}:{GIT_TOKEN}@github.com/{GIT_USER}/{GIT_REPO}.git

# 変更をコミットしてPush
# !git config --global user.email "kazuyoshi.hayase@jcom.home.ne.jp"
# !git config --global user.name "Kazuyoshi Hayase"

# !git add .
# !git commit -m "Colabからの編集：[具体的な変更内容]"
# !git push origin main
